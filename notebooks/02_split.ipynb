# %% [markdown]
# # Split

# %%
import os
import sys
import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split

warnings.filterwarnings('ignore')

# %% [markdown]
# # define functions

# %%
# During sampling, we need to check if the distributions are similar to the original data by setting a significance level 
# and using Kolmogorov-Smirnoff method.

def get_sample(df, significance = 0.05, sample_size = 5000, iterations = 100):
    for i in range(iterations):
        sample = df.sample(sample_size)
        sample_indexes = sample.index
        retrieved = True
        for var in range(df.shape[1]):
            var_sample = np.array(sample.iloc[:,var])
            metrics = ks_2samp(df.iloc[:,var], var_sample)
            pvalue = round(metrics[1], 3)
            if pvalue < significance: 
                retrieved = False
                break
        if retrieved == True: 
            print('found sample after {} iterations'.format(i+1) )
            return sample
    if not retrieved: raise ValueError("Could not build samples with {} iterations, significane={}, and sample_size={}"
                           .format(iterations,significance,sample_size))

# %% [markdown]
# # Define paths and capture data

# %%
inputs = os.path.join('..', 'data', '02_intermediate')
outputs = os.path.join('..', 'data', '02_intermediate')
reports = os.path.join('..', 'data', '06_reporting')

data = pd.read_csv(os.path.join(inputs, 'data.csv'), index_col='id')

# %%
print('Dataset dimensions:', data.shape)
data.head()
# Out:
# Dataset dimensions: (799, 13)
#     cycle  preset_1  preset_2  temperature    pressure  vibrationx  \
# id
# 0       1         3         6    44.235186   47.657254   46.441769
# 1       2         2         4    60.807234   63.172076   62.005951
# 2       3         2         1    79.027536   83.032190   82.642110
# 3       4         2         3    79.716242  100.508634  122.362321
# 4       5         2         5    39.989054   51.764833   42.514302
#
#     vibrationy  vibrationz  frequency      y  lag_1  lag_2  lag_3
# id
# 0    64.820327   66.454520  44.483250  False    NaN    NaN    NaN
# 1    80.714431   81.246405  60.228715  False    NaN    NaN    NaN
# 2    98.254386   98.785196  80.993479  False    NaN    NaN    NaN
# 3   121.363429  118.652538  80.315567  False    0.0    0.0    0.0
# 4    61.037910   50.716469  64.245166  False    0.0    0.0    0.0

# %% [raw]
# print('Dataset dimensions:', data_test.shape)
# data_test.head()

# %% [markdown]
# # data sampling
# if sampling_data == True: faster to run project, but will work on a data sample.
#
# During sampling, we need to check if the distributions are similar to the original data by setting a significance level and using Kolmogorov-Smirnoff method. See function defined in the beginning of the notebook.

# %%
from scipy.stats import ks_2samp

# %%
sampling_data = False

# %%
if sampling_data == True:
    data = get_sample(data, significance=0.05, sample_size=5000, iterations=10)
data.shape
# Out:
# (799, 13)

# %% [markdown]
# # final description

# %%
data.tail()
# Out:
#      cycle  preset_1  preset_2  temperature    pressure  vibrationx  \
# id
# 794    795         2         7   107.452875  101.617775  121.179986
# 795    796         2         6    50.469522   98.235421  151.585252
# 796    797         1         4    49.985270  160.433640  110.953010
# 797    798         1         4    79.777294  110.535405   61.334995
# 798    799         2         8    79.360314  159.985443   61.762879
#
#      vibrationy  vibrationz   frequency     y  lag_1  lag_2  lag_3
# id
# 794   80.182308   96.035159   94.125167  True    1.0    1.0    0.0
# 795   99.341380  148.838481   49.841400  True    1.0    1.0    1.0
# 796  160.777175  109.917566  110.919290  True    1.0    1.0    1.0
# 797  149.577811  129.463843   70.853353  True    1.0    1.0    1.0
# 798  169.773831  130.213426   80.113540  True    1.0    1.0    1.0

# %%
data.describe()
# Out:
#             cycle    preset_1    preset_2  temperature    pressure  \
# count  799.000000  799.000000  799.000000   799.000000  799.000000
# mean   400.000000    1.987484    4.555695    69.248987   78.958463
# std    230.795725    0.805584    2.291225    25.548948   32.502990
# min      1.000000    1.000000    1.000000     2.089354    3.480279
# 25%    200.500000    1.000000    3.000000    51.014242   55.480793
# 50%    400.000000    2.000000    5.000000    65.885436   75.000457
# 75%    599.500000    3.000000    7.000000    80.488039   99.251920
# max    799.000000    3.000000    8.000000   255.607829  189.995681
#
#        vibrationx  vibrationy  vibrationz   frequency       lag_1       lag_2  \
# count  799.000000  799.000000  799.000000  799.000000  796.000000  796.000000
# mean    73.801236   72.713120   71.843101   68.219647    0.080402    0.067839
# std     31.204488   32.693677   27.854379   29.156755    0.272086    0.251628
# min      3.846343   10.057744   18.784169    4.380101    0.000000    0.000000
# 25%     50.698623   48.498192   50.776070   45.788589    0.000000    0.000000
# 50%     69.380923   65.406638   69.308268   65.646454    0.000000    0.000000
# 75%     90.044297   94.009832   88.861568   90.118268    0.000000    0.000000
# max    230.861142  193.569947  230.951134  178.090303    1.000000    1.000000
#
#             lag_3
# count  796.000000
# mean     0.056533
# std      0.231093
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max      1.000000

# %% [markdown]
# # Split data
# test_size could depend on data size. For instance, for 1 million entries, it would work fine to establish test_size=0.1.

# %%
X = data.drop('y', axis=1)
print('dimensions of X:', X.shape)

y = data.loc[:, 'y']
y = y.astype('float')
print('dimensions of y:', y.shape)
# Out:
# dimensions of X: (799, 12)
# dimensions of y: (799,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle = False, random_state=42)
print('dimensions of X_train:', X_train.shape)
print('dimensions of y_train:', y_train.shape)
print('dimensions of X_test:', X_test.shape)
print('dimensions of y_test:', y_test.shape)
# Out:
# dimensions of X_train: (559, 12)
# dimensions of y_train: (559,)
# dimensions of X_test: (240, 12)
# dimensions of y_test: (240,)

# %%
X_train
# Out:
#      cycle  preset_1  preset_2  temperature    pressure  vibrationx  \
# id
# 0        1         3         6    44.235186   47.657254   46.441769
# 1        2         2         4    60.807234   63.172076   62.005951
# 2        3         2         1    79.027536   83.032190   82.642110
# 3        4         2         3    79.716242  100.508634  122.362321
# 4        5         2         5    39.989054   51.764833   42.514302
# ..     ...       ...       ...          ...         ...         ...
# 554    555         3         8    44.926109   45.128385   55.084454
# 555    556         1         5    59.080631   60.468110   75.435527
# 556    557         1         7    75.732972   74.688730   95.181253
# 557    558         1         8    65.867720   62.089807   44.304732
# 558    559         1         1    89.782892   93.328654   54.025396
#
#      vibrationy  vibrationz   frequency  lag_1  lag_2  lag_3
# id
# 0     64.820327   66.454520   44.483250    NaN    NaN    NaN
# 1     80.714431   81.246405   60.228715    NaN    NaN    NaN
# 2     98.254386   98.785196   80.993479    NaN    NaN    NaN
# 3    121.363429  118.652538   80.315567    0.0    0.0    0.0
# 4     61.037910   50.716469   64.245166    0.0    0.0    0.0
# ..          ...         ...         ...    ...    ...    ...
# 554   44.829898   54.419924   62.405853    1.0    1.0    1.0
# 555   59.438649   75.087669   83.777042    0.0    0.0    0.0
# 556   74.645044   95.769773  115.773835    0.0    0.0    0.0
# 557   44.142188   45.676147   45.099925    0.0    0.0    0.0
# 558   71.238085   54.401119   53.906128    0.0    0.0    0.0
#
# [559 rows x 12 columns]

# %% [markdown]
# # save train and test sets

# %%
y_train = pd.DataFrame(y_train, columns=['y'])
y_test = pd.DataFrame(y_test, columns=['y'])

X_train.to_csv(os.path.join(outputs, 'X_train.csv'))
X_test.to_csv(os.path.join(outputs, 'X_test.csv'))
y_train.to_csv(os.path.join(outputs, 'y_train.csv'))
y_test.to_csv(os.path.join(outputs, 'y_test.csv'))
